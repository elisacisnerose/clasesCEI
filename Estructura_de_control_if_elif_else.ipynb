# %% [markdown]
# <a href="https://colab.research.google.com/github/elisacisnerose/clasesCEI/blob/main/Estructura_de_control_if_elif_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fundamentos de Python y estructuras de control

# %% [markdown]
# ## Estructuras de control: if-elif-else

# %% [markdown]
# ### Control if

# %% [markdown]
# La estructura de control **if** permite que un programa ejecute unas instrucciones cuando se cumple una o varias condiciones.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Si transformamos este diagrama de flujo a Python, sería algo como:

# %%
velocidad = 120
if velocidad > 120:
  print("Multa. La velocidad máxima es 120")

print("Ha pasado usted por un control de velocidad.")
# Out:
# Ha pasado usted por un control de velocidad.

# %% [markdown]
# Paso a paso, cabe destacar:
# * La primera línea de la estructura de control contiene la expresión a evaluar. Como hemos visto anteriormente, estas expresiones devuelven True o False. Si la expresión devuelve True, ejecuta las instrucciones que vienen a continuación.
# * Para que Python "sepa" que no hay nada más que evaluar, es necesario acabar la línea con **":"**.
# * En el bloque de instrucciones a ejecutar, lo que hará que Python sepa qué instrucciones son las que están incluidas en la condición es la **sangría del texto**. (Cuando utilicemos intérpretes como jupyter notebook o Google Collab, la sangría del texto la hará de manera automática).
# * Cuando terminemos de ejecutar el bloque de instrucciones, bastará con eliminar la sangría y volver al nivel anterior.

# %% [markdown]
# ### Control if - else

# %% [markdown]
# La estructura **if-else** permite que un programa ejecute una serie de instrucciones cuando se cumplan unas condiciones, y ejecute otras instrucciones cuando no se cumplan.
#
# ![image.png](data:image/png;base64,...)
#
# Llevado a código, esto sería algo como:

# %%
edad = 18
if edad <= 18.0:
  print("Usted es menor de edad")
else:
  print("Usted es mayor de edad. Puede pasar")
# Out:
# Usted es menor de edad

# %% [markdown]
# Esta estructura de tipo **if-else** puede construirse también concatenando dos estructuras de tipo **if**, pero esto no es recomendable, ya que, si ponemos dos estructuras **if**, obligamos a Python a evaluar ambas. En cambio, con la estructura **if-else**, con que evalúe una ya sabe cuál de las dos tiene que ejecutar.

# %%
edad = 19
if edad < 18:
    print("Usted es menor de edad")
if edad >= 18:
  print("Usted es mayor de edad. Puede pasar")

# %% [markdown]
# **Sentencias anidadas**
#
# Una sentencia **if-else** puede contener a su vez otra condición anidada.

# %%
edad = 18
autorizacion = True
if edad < 18:
  if autorizacion:
    print("Usted es menor pero tiene autorización. Puede pasar")
  else:
    print("Usted es menor de edad. Si no viene con autorización no puede pasar.")
else:
  print("Usted es mayor de edad. Puede pasar")
# Out:
# Usted es menor pero tiene autorización. Puede pasar

# %% [markdown]
# ### Control if - elif - else

# %% [markdown]
# Hasta ahora hemos visto situaciones en las que se podían evaluar 1 o 2 condiciones pero, ¿qué pasa si una situación requiere evaluar más de dos condiciones?
#
# Para ello tenemos la estructura **if - elif - else**.
#
# ![image.png](data:image/png;base64,...)
#
# Llevado a código Python, esta estructura quedaría como:

# %%
edad = 0
if edad < 0:
  print("Error. La edad no puede ser negativa")
elif edad < 18:
  print("Usted es menor de edad")
elif edad > 120:
  print("Enhorabuena. Es usted la persona más longeva del mundo")
else:
  print("Usted es mayor de edad. Puede pasar")
# Out:
# Usted es menor de edad

# %% [markdown]
# #### IF anidados

# %%
genero = input("Por favor, introduzca su género (H o M): ")
talla = input("Por favor, introduzca su talla (S, M, L o XL): ")

if genero == 'M':
  if talla == 'L':
    print("No hay stock de esta talla")
  elif talla in ('S', 'XL'):
    print("Quedan pocas unidades. ¡Date prisa!")
  elif talla == 'M':
    print("Artículo disponible")
  else:
    print("Por favor, introduzca una talla correcta (S, M, L o XL)")
elif genero == 'H':
  if talla in ("S", "M", "XL"):
    print(f"La talla {talla} no tiene stock")
  elif talla == 'L':
    print("Artículo disponible")
  else:
    print("Introduzca una talla correcta (S, M, L o XL)")
else:
  print("Introduzca un género aceptado en el sistema (H o M)")
# Out:
# Por favor, introduzca su género (H o M): H
# Por favor, introduzca su talla (S, M, L o XL): XXL

# %% [markdown]
# ### Posibles errores

# %% [markdown]
# En este tipo de estructuras de control, es muy importante que las condiciones estén evaluadas de manera ordenada, y contemplar todas las casuísticas posibles.

# %%
a = 3
b = 5

if a > b:
  print("A es mayor que B")
else:
  print("B es mayor que A")

# %% [markdown]
# A priori puede parecer que el ejemplo visto anteriormente es correcto pero, ¿ha contemplado todas las posibles casuísticas? ¿Y si A y B son iguales?

# %%
i = 3
if i > 3:
  print("La variable es mayor que 3")
elif i > 2:
  print("La variable es mayor que 2")
elif i > 1:
  print("La variable es mayor que 1")
else:
  print("La variable es 1 o menor")
# Out:
# La variable es mayor que 2

# %% [markdown]
# El caso anterior contempla todas las casuísticas y parece correcto pero, ¿es coherente? ¿Tiene condiciones innecesarias?

# %% [markdown]
# ### Ejercicios

# %% [markdown]
# #### Completar ejercicios módulo anterior
#
# Email docente: pythonvalencia@profesorado.cei.es

# %% [markdown]
# 1. Escriba un programa que pida al usuario introducir el ancho y el alto de un rectángulo, y el programa devuelva el área, el perímetro y la diagonal del rectángulo. En caso de que el ancho y el alto sean de igual tamaño o alguno sea negativo, mostrar un aviso de error y no realizar el cálculo.
# 2. Escriba un programa que pida el peso (en kg) y la altura (en metros) de una persona y le calcule su índice de masa corporal. Nota: imc = peso/altura^2. En caso de que el peso o la altura sean inferior a 0, mostrar aviso de error y no realizar el cálculo.
# * Si IMC < 18,5 --> Delgado
# * Si IMC entre 18,5 y  25 --> Normal
# * Si IMC entre 25 y 35 --> Obeso I
# * Si IMC > 35 --> Obeso II
#
# 18.5 <= imc < 25:
#
#
# 3. Escriba un programa que pida al usuario que introduzca una frase en la consola y una vocal. Después, muestre por pantalla la misma frase pero con la vocal introducida en mayúscula. En caso de que el caracter introducido como vocal no sea una vocal o tenga longitud distinta de 1, mostrar un error.
# 4. Escriba un programa que pida al usuario introducir una frase, y nos muestre por pantalla si es un palíndromo o no. En caso de ser correcto, mostrar un mensaje de felicitación. En caso de que no, mostrar mensaje de error.
# 5. Escriba un programa que reciba el número de respuestas correctas e incorrectas de un test y calcule la nota del examen. Tenga en cuenta que las respuestas correctas suman 1 punto y las incorrectas restan 0.4 puntos. El número de respuestas correctas o incorrectas no puede ser menor que 0 o mayor que 10. La suma de respuestas correctas e incorrectas debe sumar como mucho 10. En caso de que no se cumpla alguna condición, mostrar mensaje de error.

# %% [markdown]
# #### Nuevos ejercicios

# %% [markdown]
# 1.   Escribir un programa que reciba un número y muestre si es múltiplo de 3.
#
# 2.   Escribir un programa que reciba un número e imprima diferentes salidas, en base a las siguientes condiciones:
#
#
# * El número es negativo.
# * El número es igual a 0.
# * El número está entre 0 y 5 o es mayor que 30.
# * El número está entre 5 y 30.
#
# 3. Escriba un programa que pida dos números y que conteste cuál es el menor y cuál el mayor o que escriba que son iguales.
#
# 3. Escriba un programa que pida un número par y, si no es correcto, muestre un aviso. En caso de ser correcto, le pedirá un número impar. En caso de que no sea correcto, mostrará un aviso.
#
# 4. Los alumnos de un curso se han dividido en dos grupos A y B de acuerdo al sexo y el nombre. El grupo A esta formado por las mujeres con un nombre anterior a la M y los hombres con un nombre posterior a la N y el grupo B por el resto. Escribir un programa que pregunte al usuario su nombre y sexo, y muestre por pantalla el grupo que le corresponde.
#
# 5. Escriba un programa que pida el año actual y un año cualquiera, y nos muestre por pantalla cuántos años han pasado desde ese año o cuántos años faltan para llegar a ese año.
