# %% [markdown]
# <a href="https://colab.research.google.com/github/elisacisnerose/clasesCEI/blob/main/7_Estructuras_de_datos_Listas_y_tuplas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fundamentos de Python y estructuras de control

# %% [markdown]
# ## Estructuras de datos

# %% [markdown]
# Python nos ofrece una serie de estructuras de datos en las cuales podemos almacenar nuestros datos de manera ordenada y con posibilidad de acceder a ellos de manera lógica. Hay cuatro tipos de estructura:
#
# * **Listas**
#
# > * Datos heterogéneos
# * Acepta repetidos
# * Elementos mutables
# * Accesibles por índice
# >
#
# * **Tuplas**
#
# > * Datos heterogéneos
# * Acepta repetidos
# * Elementos **inmutables**
# * Accesibles por índice
# >
#
# * **Conjuntos**
#
# > * Datos heterogéneos
# * **No admite repetidos**
# * Elementos **inmutables**
# * **No accesibles por índice**
# >
#
# * **Diccionarios**
#
# > * Datos heterogéneos
# * Acepta repetidos
# * Claves de tipos **inmutables y únicas**
# * **Accesibles por clave**

# %% [markdown]
# ### Listas

# %% [markdown]
# #### Características y tratamiento listas

# %% [markdown]
# Las listas son la estructura de datos más flexible de Python.
# Las listas se delimitan por corchetes **[ ]** y los elementos se separan por comas.

# %%
lista = list()
lista = []

# %%
lista = ["Diego", 34, True] # Datos heterogéneos
lista = [3,3,5,10,5]        # Acepta repetidos
lista[2] = 4                # Elementos mutables
print(lista[1])             # Elementos accesibles por índice
# Out:
# 3

# %% [markdown]
# Podemos crear una lista a base de recoger otras variables sueltas

# %%
nombre = "Pedro"
edad = 31
carnet_conducir = True
lugar = "Madrid"
lista = [nombre, edad, carnet_conducir, lugar]
print(lista)
# Out:
# ['Pedro', 31, True, 'Madrid']

# %% [markdown]
# Una lista puede tener a su vez otra lista dentro

# %%
datos_Otro = ["Pedro", 38, False, "Valladolid"]
datos = [lista, datos_Otro]

# %%
print(datos)
# Out:
# [['Pedro', 31, True, 'Madrid'], ['Pedro', 38, False, 'Valladolid']]

# %% [markdown]
# Existen muchas funciones a las que podemos hacer referencia si queremos trabajar con lista. Algunas son de secuencias (genéricas) y otras específicas para listas.
#
# **Slicing:** técnica que te permite acceder a una porción de una secuencia (como una lista, tupla, cadena de texto, etc.) de manera muy sencilla. Consiste en especificar un rango de índices para extraer una sub-secuencia.
#
# *   secuencia[inicio:fin:paso]
# *   inicio: Es el índice donde empieza el slicing (inclusive).
# *   fin: Es el índice donde termina el slicing (exclusivo).
# *   paso: Es el intervalo entre los índices (opcional).

# %%
# FUNCIONALIDADES DE SECUENCIAS
nombres = ["Diego", "Elena", "Araceli", "Pedro", "Valeria"] # De izquierda a derecha, inicia en cero. De derecha a izquierda, inicia en -1
# print(nombres[2])             # Accedemos a posición concreta
# print(nombres[-3])            # Accedemos a posición en orden inverso
# print(nombres[1:3])           # Podemos hacer slicing
# print(nombres[::2])           # Slicing con salto
# print(nombres + [1,2,3])      # Concatenar listas
# print(nombres*2)              # Multiplicar listas
# print("Lara" in nombres)      # Membresía
# print("Lara" not in nombres)  # Caso contrario. Comprobamos que el elemento no esté
# Out:
# True

# %%
numeros = [2,5,7,8,1]
numerosDeFinAPrincipio = numeros[::-1]
print(numerosDeFinAPrincipio)
# Out:
# [1, 8, 7, 5, 2]

# %%
# FUNCIONALIDADES DE SECUENCIAS
mi_lista = [1,2,5,10,20,30]

print(len(mi_lista))      # Tamaño de la lista
print(min(mi_lista))      # Valor mínimo de la lista.
print(max(mi_lista))      # Valor máximo de la lista.
print(mi_lista.count(2))  # Cuenta número apariciones de un valor
print(mi_lista.index(5))  # Muestra el índice de la primera aparición de un valor
# Out:
# 6
# 1
# 30
# 1
# 2

# %%
# FUNCIONES ESPECIFICAS PARA LISTAS
nombres = ["Diego", "Elena", "Araceli", "Pedro", "Valeria"]
# nombres.append("Lara") ## agregar un valor a la lista
# nombres.append(["Juan", "Rocío"])
# nombres.append("Juan", "Rocío") # NO es posible agregar con append varios elementos de la lista al mismo tiempo
# nombres.extend(["Juan", "Rocio" ]) # Para ello utilizamos extend
# nombres.remove("Diego")
# nombres.pop() # elimina el ultimo elemento de la lista
# nombres.pop(-2) # elimina el 2do registro de derecha a izquierda
# del nombres[0] # elimina el registro con indice cero
# del nombres[-1] # elimina el primer registro de derecha a izquierda
# nombres.insert(2, "Manuel") # inserta un registro en la posicion dada
# nombres.reverse() # cambia el orden de la lista a modo reverso
nombres.sort(reverse = True) # ordena la lista
print(nombres)
# Out:
# ['Valeria', 'Pedro', 'Elena', 'Diego', 'Araceli']

# %% [markdown]
# #### Cómo recorrer una lista

# %% [markdown]
# Se puede recorrer una lista de principio a fin de varias maneras (siempre con bucle for).
# * Una forma es recorrer directamente los elementos de lista (es decir, los elementos iterables serán los propios elementos de la lista).

# %%
letras = ["A", "B", "C"]
for i in letras:
  print(i)
# Out:
# A
# B
# C

# %% [markdown]
# * La otra forma es recorrer indirectamente los elementos de la lista. Es decir, los elementos iterables serán los índices de la lista. De este modo podremos manipular los elementos de manera más sencilla en caso de que así lo deseemos.

# %%
letras = ["A", "B", "C"]
for i in range(len(letras)):
  print(letras[i])
# Out:
# A
# B
# C

# %% [markdown]
# **Recorrer una lista al revés**

# %%
letras = ["A", "B", "C"]
letras.reverse() # aplica el modo reverso de la listta
for i in letras:
  print(i)
# Out:
# C
# B
# A

# %%
letras = ["A", "B", "C"]
for i in range(len(letras)-1, -1, -1):
  print(letras[i])
# Out:
# C
# B
# A

# %% [markdown]
# **Modificar elementos de una lista**

# %%
letras = ["A", "B", "C"]
for i in range(len(letras)):
  letras[i] = 'X'
  print(letras)
# Out:
# ['X', 'B', 'C']
# ['X', 'X', 'C']
# ['X', 'X', 'X']

# %% [markdown]
# #### Ejercicios

# %% [markdown]
# 1. Escriba un programa que multiplique por 5 cada elemento de una lista, creando una nueva lista con el resultado.
#
# lista = [1,2,3,4,5]lista1 = []
#
# for i in range(len(lista)):
#
#   lista1.append(lista[i]*5)
#
# lista1
#
# 2. Escriba un programa que guarde en una nueva lista los valores contenidos en las posiciones impares de la lista inicial.
#
# numero = int(input("Ingrese un número: "))
#
# divisores = []
#
# for i in range(1, numero + 1):
#
#     if numero % i == 0:
#
#         divisores.append(i)
#
# print("Divisores de ", numero, " son: ", divisores)
#
#
# 3. Escriba un programa que pida un número, y a continuación escriba la lista de todos los divisores (cantidad por la cual se divide otra) de ese número (incluido el 1 y él mismo).
#
# # 3
# numero = int(input("Ingrese un número: "))
#
# divisores = []
#
#
# for i in range(1, numero + 1):
#
#     if numero % i == 0:
#
#         divisores.append(i)
#
#
# print("Divisores de ", numero, " son: ", divisores)
#
#
# 4. Escriba un programa que pida el número de palabras que va a contener una lista. Después, el usuario introducirá tantas palabras como ha dicho que iba a tener. Finalmente el programa le pedirá al usuario una palabra y comprobará si está incluida en la lista creada.
#
# # 4
# cantidad=int(input("Ingresa cantidad de palabras:"))
#
# lista=[]
#
# for i in range(cantidad):
#   palabra=input("Ingresa palabra:")
#   lista.append(palabra)
#
#
# nuevaPalabra=input("Ingresa nueva palabra:")
#
# if nuevaPalabra in lista:
#     print("La palabra", nuevaPalabra, "está en la lista.")
#
# else:
#     print("La palabra", nuevaPalabra, "no está en la lista.")
#
#
#
# 5. Escribir un programa que almacene en una lista las asignaturas de un curso (por ejemplo Matemáticas, Lengua, Física, Química, Historia e Inglés),le pregunte al usuario la nota que ha sacado en cada asignatura y elimine de la lista aquellas asignaturas que ha aprobado. Al final, el programa debe mostrar por pantalla las asignaturas que el usuario tiene que repetir.
#
# materias = ["Matemáticas", "Lengua", "Física", "Química", "Historia", "Inglés"]
#
# notas=[]
#
#
# for i in range(len(materias)-1, -1, -1):
#
#   nota = int(input("Ingresa la nota de " + materias[i] + ": "))
#
#   notas.append(nota)
#
#   if nota > 5:
#
#     del materias[i]
#
#     del notas[i]
#
#
# print("Materias que debe repetir: ")
#
# print(materias)
#
#
# 6. Escribir un programa que le pida al usuario una frase y devuelva por pantalla el número de veces que aparece cada vocal.
#
# frase=input("Ingresa una frase:")
#
# cantidad_a = frase.count("a")
#
# cantidad_e = frase.count("e")
#
# cantidad_i = frase.count("i")
#
# cantidad_o = frase.count("o")
#
# cantidad_u = frase.count("u")
#
# print(cantidad_a, cantidad_e, cantidad_i, cantidad_o, cantidad_u)

# %% [markdown]
# ### Tuplas

# %% [markdown]
# Las tuplas son estructuras de datos casi idénticas a las listas, con la diferencia de que sus elementos son inmutables, y la manera de declararlas es mediante **( )**.

# %%
tupla = () # tupla vacía
tupla = (0,) # esto es una tupla con un solo elemento
tupla = (0)  # esto no es una tupla, sino un número entero (int).

# %%
tupla = ("Pedro", 34, True)  # Datos heterogéneos
tupla2 = (3,3,5,10,5)        # Acepta repetidos
print(tupla2[3])             # Elementos accesibles por índice
# Out:
# 10

# %% [markdown]
# Podemos crear una tupla a base de recoger otras variables sueltas

# %%
nombre = "Pedro"
edad = 31
carnet_conducir = True
lugar = "Valencia"

tupla = (nombre, edad, carnet_conducir, lugar)
print(tupla)
print(type(tupla))
# Out:
# ('Pedro', 31, True, 'Valencia')
# <class 'tuple'>

# %% [markdown]
# Las tuplas aceptan aquellos comandos de secuencia que no modifican la tupla.

# %%
nombres = ("Juan", "Elena", "Araceli", "Pedro", "Valeria")
# print(nombres[0])             # Accedemos a posición concreta
# print(nombres[-1])            # Accedemos a posición en orden inverso
# print(nombres[1:3])           # Podemos hacer slicing
# print(nombres[::2])           # Slicing con salto
# print(nombres*2)              # Multiplicar listas
# print("Lara" in nombres)      # Membresía
# print("Lara" not in nombres)  # Caso contrario. Comprobamos que el elemento no esté
# Out:
# False

# %%
# FUNCIONALIDADES DE SECUENCIAS
tupla = (1,2,5,10,20,30)

print(len(tupla))      # Tamaño de la lista
print(min(tupla))      # Valor mínimo de la lista.
print(max(tupla))      # Valor máximo de la lista.
print(tupla.count(2))  # Cuenta número apariciones de un valor
print(tupla.index(2))  # Muestra el índice de la primera aparición de un valor
# Out:
# 6
# 1
# 30
# 1
# 1

# %% [markdown]
# Ya hemos visto que las tuplas son inmutables, ¿pero qué pasa si queremos modificar un elemento?

# %%
mi_tupla = (1,2,5,10,20,30)
mi_tupla[2] = 19
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-9a0442189099> in <cell line: 0>()
#       1 mi_tupla = (1,2,5,10,20,30)
# ----> 2 mi_tupla[2] = 19
#
# TypeError: 'tuple' object does not support item assignment

# %%
mi_lista = list(mi_tupla) # crear una lista a partir de una tupla
mi_lista[2] = 19
print(mi_lista, type(mi_lista))
del mi_lista
print(mi_tupla, type(mi_tupla))
# Out:
# [1, 2, 19, 10, 20, 30] <class 'list'>
# (1, 2, 5, 10, 20, 30) <class 'tuple'>

# %% [markdown]
# **¡Ojo!** Las tuplas son inmutables, pero sus elementos no. Es decir, si tenemos dentro de una tupla una lista, esta sí podremos modificarla.

# %%
tupla = (0,1,2,3, ["Diego", 31])
#print(tupla)
print(tupla[4][0], tupla[4][1])
#tupla[4][1] = 32
#print(tupla[4][0], tupla[4][1])
# Out:
# Diego 31

# %% [markdown]
# #### Ejercicios

# %% [markdown]
# 1.  Escriba un programa que cambie el primer valor de la tupla por un 1.
# 2. Escriba un programa que cuente cuántas veces aparece un nombre en una tupla.
# tupla = ("Ana", "Pedro", "María", "Ana", "Juan", "ana")
# 3. Escriba un programa que analice la tupla anterior de nombres y devuelva solo los elementos que tengan 5 caracteres.
#
# 4. Tenemos en una tupla guardadas una serie de recetas. En cada posición de la tupla tenemos una lista en la que guardamos el nombre de la comida, los gramos de aceite, los pellizcos de sal neesarios y los minutos que hay que cocinarlo. Escriba un programa que nos pida la comida que queremos cocinar y nos devuelva el aceite, la sal y el tiempo necesario de cocinado.
#
# 5. Tenemos en una tupla a los empleados de nuestra tienda, junto al número de televisiones que vendieron el día anterior y el importe total de sus ventas. Escriba un programa que nos devuelva el nombre del empleado que vendió más televisiones, el nombre del empleado que más facturó el día anterior y el nombre del empleado con el peor ticket medio del día (ticket medio = importe/numero).

# %% [markdown]
# # 2
# tupla = ("Ana", "Pedro", "María", "Ana", "Juan", "ana")
#
# nombre = input("Ingresa nombre:")
#
# contador = 0
#
#
# for nombre1 in tupla:
#
#     if nombre1 == nombre:
#
#         contador += 1
#
#
# print(contador)

# %% [markdown]
# # 3
# tupla = ("Ana", "Pedro", "María", "Ana", "Juan", "ana")
#
# nombres_5_caracteres = []
#
#
# for nombre in tupla:
#
#     if len(nombre) == 5:
#
#         nombres_5_caracteres.append(nombre)
#
#
# nombres_5_caracteres

# %% [markdown]
# # 4
# recetas = (
#     ["Pizza", 75, 2, 30],
#     ["Hamburguesa", 85, 3, 25],
#     ["Ensalada", 40, 1, 15],
#     ["Sushi", 90, 2, 45],
#     ["Pasta", 70, 2, 20],
#     ["Tacos", 80, 3, 35],
#     ["Sopa", 60, 1, 10],
#     ["Pollo a la parrilla", 65, 2, 20],
#     ["Burrito", 75, 3, 30],
#     ["Filete de pescado", 85, 2, 25],
#     ["Sándwich", 70, 2, 20],
#     ["Camarones al ajillo", 95, 1, 50],
#     ["Canelones", 60, 2, 20],
#     ["Arroz frito", 80, 3, 35],
#     ["Pollo al curry", 75, 2, 30],
#     ["Tortilla española", 70, 1, 25],
#     ["Costillas a la barbacoa", 90, 3, 45],
#     ["Sopa de lentejas", 55, 1, 10],
#     ["Tostadas francesas", 80, 2, 30],
#     ["Tiramisú", 95, 1, 45]
# )
#
#
# comida = input("¿Qué comida quieres cocinar? ")
#
#
# encontrada = False
#
# for receta in recetas:
#
#     if receta[0].lower() == comida.lower():
#
#         aceite = receta[1]
#
#         sal = receta[2]
#
#         tiempo = receta[3]
#
#         print(f"Para hacer {comida} necesitas:")
#
#         print(f"- {aceite} gramos de aceite")
#
#         print(f"- {sal} pellizcos de sal")
#
#         print(f"- {tiempo} minutos de cocción")
#
#         encontrada = True
#
#         break
#
#
# if not encontrada:
#
#     print(f"No se encontró la receta para {comida}")

# %% [markdown]
# # 5
# key=lambda x: x[1]: Aquí se le indica a la función max() que utilice el segundo valor (índice 1) de cada elemento para hacer la comparación. Es decir, la función lambda toma cada elemento x de la lista empleados y le devuelve x[1], el segundo valor dentro de cada elemento.
#
# Entonces, mas_televisores = max(empleados, key=lambda x: x[1]):
#
# Está buscando el "empleado" que tenga el valor máximo en el segundo elemento de la tupla/lista.
#
# empleados = (
#     ["Juan", 8, 3500],
#     ["María", 6, 4800],
#     ["Pedro", 9, 6200],
#     ["Ana", 5, 2700],
#     ["Luis", 7, 5600],
#     ["Sofía", 4, 4100],
#     ["Carlos", 3, 1800],
#     ["Laura", 8, 7400],
#     ["Miguel", 2, 1200],
#     ["Elena", 7, 6900],
#     ["David", 6, 3900],
#     ["Carmen", 9, 8500],
#     ["Javier", 5, 3200],
#     ["Isabel", 7, 5800],
#     ["Roberto", 8, 7200]
# )
#
# # Empleado con más televisiones vendidas
#
# mas_televisores = max(empleados, key=lambda x: x[1])
#
# print(mas_televisores)
#
# nombre_mas_televisores = mas_televisores[0]
#
# mas_televisoresVarios = [e for e in empleados if e[1] == mas_televisores[1]]
#
# print(mas_televisoresVarios)
#
#
#
# # Empleado con mayor importe total de ventas
#
# mas_facturacion = max(empleados, key=lambda x: x[2])
#
# print(mas_facturacion)
#
# nombre_mas_facturacion = mas_facturacion[0]
#
#
# # Empleado con peor ticket medio
#
# peor_ticket_medio = min(empleados, key=lambda x: x[2] / x[1] if x[1] != 0 else 0)
#
# print(peor_ticket_medio)
#
# nombre_peor_ticket = peor_ticket_medio[0]
#
#
# print(f"Empleado que vendió más televisores:
# {nombre_mas_televisores}")
#
# print(f"Empleado con mayor facturación: {nombre_mas_facturacion}")
#
# print(f"Empleado con peor ticket medio: {nombre_peor_ticket}")

# %%
comidas = (
    ["Pizza", 75, 2, 30],
    ["Hamburguesa", 85, 3, 25],
    ["Ensalada", 40, 1, 15],
    ["Sushi", 90, 2, 45],
    ["Pasta", 70, 2, 20],
    ["Tacos", 80, 3, 35],
    ["Sopa", 60, 1, 10],
    ["Pollo a la parrilla", 65, 2, 20],
    ["Burrito", 75, 3, 30],
    ["Filete de pescado", 85, 2, 25],
    ["Sándwich", 70, 2, 20],
    ["Camarones al ajillo", 95, 1, 50],
    ["Canelones", 60, 2, 20],
    ["Arroz frito", 80, 3, 35],
    ["Pollo al curry", 75, 2, 30],
    ["Tortilla española", 70, 1, 25],
    ["Costillas a la barbacoa", 90, 3, 45],
    ["Sopa de lentejas", 55, 1, 10],
    ["Tostadas francesas", 80, 2, 30],
    ["Tiramisú", 95, 1, 45]
)


personas = (
    ["Juan", 8, 3500],
    ["María", 6, 4800],
    ["Pedro", 9, 6200],
    ["Ana", 5, 2700],
    ["Luis", 7, 5600],
    ["Sofía", 4, 4100],
    ["Carlos", 3, 1800],
    ["Laura", 8, 7400],
    ["Miguel", 2, 1200],
    ["Elena", 7, 6900],
    ["David", 6, 3900],
    ["Carmen", 9, 8500],
    ["Javier", 5, 3200],
    ["Isabel", 7, 5800],
    ["Roberto", 8, 7200]
)

# %% [markdown]
# **Desafío**: Sistema de registro de peliculas
#
# MENU DE OPCIONES
#
# 1, Ingresar película
# 	Nombre
# 	Año
# 	Género
# 	Calificación
# 	Lista de actores
#
# 2. Mostrar las películas en las que participa un actor ingresado por pantalla. No hace falta ingresar el nombre completo, solo con alguna parte del nombre debe buscar
#
# 3. Mostrar las películas de un género ingresado por pantalla
#
# 4. Mostrar las películas cuya calificación sea superior o igual a una ingresada por pantalla
#
# 5. Mostrar las películas cuyo nombre sea uno ingresado por pantalla
#
# 6. Cerrar programa
#
# Aclaraciones:
# * Si quieres mejorar tu programa, puedes obtener un listado de películas, en formato csv, luego leer el mismo desde python y cargar la lista de películas
# * Otra mejora, puede ser de agregar un filtro múltiple, es decir, el usuario puede filtrar al mismo tiempo por nombre, año, género, calificación y/o nombre de actor.

# %%
peliculas = [
    {
        "nombre": "El Padrino",
        "año": 1972,
        "género": "Crimen, Drama",
        "calificación": 9.2,
        "actores": ["Marlon Brando", "Al Pacino", "James Caan"]
    },
    {
        "nombre": "La guerra de las galaxias: Episodio IV - Una nueva esperanza",
        "año": 1977,
        "género": "Aventura, Ciencia ficción",
        "calificación": 8.6,
        "actores": ["Mark Hamill", "Harrison Ford", "Carrie Fisher"]
    },
    {
        "nombre": "El caballero oscuro",
        "año": 2008,
        "género": "Acción, Crimen, Drama",
        "calificación": 9.0,
        "actores": ["Christian Bale", "Heath Ledger", "Aaron Eckhart"]
    },
    {
        "nombre": "Forrest Gump",
        "año": 1994,
        "género": "Drama, Romance",
        "calificación": 8.8,
        "actores": ["Tom Hanks", "Robin Wright", "Gary Sinise"]
    },
    {
        "nombre": "Pulp Fiction",
        "año": 1994,
        "género": "Crimen, Drama",
        "calificación": 8.9,
        "actores": ["John Travolta", "Uma Thurman", "Samuel L. Jackson"]
    },
    {
        "nombre": "El Señor de los Anillos: La Comunidad del Anillo",
        "año": 2001,
        "género": "Aventura, Fantasía",
        "calificación": 8.8,
        "actores": ["Elijah Wood", "Ian McKellen", "Viggo Mortensen"]
    },
    {
        "nombre": "Titanic",
        "año": 1997,
        "género": "Drama, Romance",
        "calificación": 7.8,
        "actores": ["Leonardo DiCaprio", "Kate Winslet", "Billy Zane"]
    },
    {
        "nombre": "La lista de Schindler",
        "año": 1993,
        "género": "Biografía, Drama, Historia",
        "calificación": 9.0,
        "actores": ["Liam Neeson", "Ben Kingsley", "Ralph Fiennes"]
    },
    {
        "nombre": "Matrix",
        "año": 1999,
        "género": "Acción, Ciencia ficción",
        "calificación": 8.7,
        "actores": ["Keanu Reeves", "Laurence Fishburne", "Carrie-Anne Moss"]
    },
    {
        "nombre": "Inception",
        "año": 2010,
        "género": "Acción, Ciencia ficción, Suspenso",
        "calificación": 8.8,
        "actores": ["Leonardo DiCaprio", "Joseph Gordon-Levitt", "Elliot Page"]
    },
    {
        "nombre": "Gladiator",
        "año": 2000,
        "género": "Acción, Aventura, Drama",
        "calificación": 8.5,
        "actores": ["Russell Crowe", "Joaquin Phoenix", "Connie Nielsen"]
    },
    {
        "nombre": "El origen del planeta de los simios",
        "año": 2011,
        "género": "Acción, Aventura, Ciencia ficción",
        "calificación": 7.6,
        "actores": ["James Franco", "Andy Serkis", "Freida Pinto"]
    },
    {
        "nombre": "Vengadores: Endgame",
        "año": 2019,
        "género": "Acción, Aventura, Ciencia ficción",
        "calificación": 8.4,
        "actores": ["Robert Downey Jr.", "Chris Evans", "Scarlett Johansson"]
    },
    {
        "nombre": "El resplandor",
        "año": 1980,
        "género": "Terror, Drama",
        "calificación": 8.4,
        "actores": ["Jack Nicholson", "Shelley Duvall", "Danny Lloyd"]
    },
    {
        "nombre": "Interstellar",
        "año": 2014,
        "género": "Aventura, Drama, Ciencia ficción",
        "calificación": 8.6,
        "actores": ["Matthew McConaughey", "Anne Hathaway", "Jessica Chastain"]
    },
    {
        "nombre": "La naranja mecánica",
        "año": 1971,
        "género": "Crimen, Drama, Ciencia ficción",
        "calificación": 8.3,
        "actores": ["Malcolm McDowell", "Patrick Magee", "Michael Bates"]
    },
    {
        "nombre": "Terminator 2: Judgment Day",
        "año": 1991,
        "género": "Acción, Ciencia ficción",
        "calificación": 8.5,
        "actores": ["Arnold Schwarzenegger", "Linda Hamilton", "Edward Furlong"]
    },
    {
        "nombre": "La forma del agua",
        "año": 2017,
        "género": "Aventura, Drama, Fantasía",
        "calificación": 7.3,
        "actores": ["Sally Hawkins", "Michael Shannon", "Richard Jenkins"]
    },
    {
        "nombre": "El lobo de Wall Street",
        "año": 2013,
        "género": "Biografía, Comedia, Crimen",
        "calificación": 8.2,
        "actores": ["Leonardo DiCaprio", "Jonah Hill", "Margot Robbie"]
    },
    {
        "nombre": "Coco",
        "año": 2017,
        "género": "Animación, Aventura, Comedia",
        "calificación": 8.4,
        "actores": ["Anthony Gonzalez", "Gael García Bernal", "Benjamin Bratt"]
    }
]
