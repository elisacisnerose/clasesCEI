# %% [markdown]
# <a href="https://colab.research.google.com/github/elisacisnerose/clasesCEI/blob/main/Tipos_de_datos_y_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fundamentos de Python y estructuras de control - Juan Manuel Romero

# %% [markdown]
# ## Tipos de datos

# %% [markdown]
# ### Numéricos

# %% [markdown]
# Python distingue entre números enteros y decimales.
# Para ello, usaremos el delimitador "." cuando queramos referirnos a un número decimal (sistema americano).

# %%
3     # Número entero
4.5   # Número decimal
5,6   # En este caso, Python interpretará que estamos creando una tupla con dos elementos
3.0   # En este caso, Python interpretará este valor como número decimal (aunque la parte decimal sea cero)
.4    # Se puede escribir un número decimal sin la parte entera, aunque lo habitual sea poner primero la parte entera

100_000         # Si queremos delimitar los miles/millones en una cifra, Python permite utilizar el guión bajo para ello (aunque se puede utilizar en cualquier posición)
100_000.000_001 # El delimitador también lo podremos utilizar en valores decimales

# %%
1_000_000
# Out:
# 1000000

# %% [markdown]
# ####Operaciones básicas

# %% [markdown]
# Las cuatro operaciones básicas son la suma, la resta, la multiplicación y la división.
#
# Para cualquiera de estas operaciones, siempre que intervenga algún número decimal, el resultado será un número decimal. En el caso de que el resultado sea un número exacto, se escribirá "0" en la parte decimal.

# %%
2.5*3
# Out:
# 7

# %%
2.5*4
# Out:
# 10

# %% [markdown]
# Al sumar, restar o multiplicar números enteros, el resultado es entero

# %%
10+4
# Out:
# 14

# %%
3-30
# Out:
# -27

# %%
11*3
# Out:
# 33

# %% [markdown]
# En cambio, si dividimos números enteros, el resultado siempre será decimal aunque la parte decimal sea cero.

# %%
10/2
# Out:
# 5.0

# %%
10/4
# Out:
# 2.5

# %% [markdown]
# Si realizamos una división entre 0, Python nos devuelve un error.

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-18-9e1622b385b6> in <cell line: 1>()
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# En el caso de que queramos realizar varias operaciones de manera consecutiva, Python utiliza las reglas típicas de prioridad (primero multiplicaciones y divisiones, y después sumar y restas).
# En el caso de que nos interese que las operaciones se realicen en otro orden, debemos utilizar paréntesis para encapsular las operaciones.

# %%
9+5*2
# Out:
# 19

# %%
(9+5)*2
# Out:
# 28

# %% [markdown]
# Una peculiaridad de Python es que podemos escribir sumas y restas seguidas (sin literales), pero no es lo adecuado, ya que no representa una notación habitual.
# Esta peculiaridad no se aplica para las multiplicaciones y divisiones.

# %%
#10++-+4
10+(1*1*(-1))
# Out:
# 6

# %%
10**/*4

# %% [markdown]
# #### Cociente y resto de una división

# %% [markdown]
# Una división está compuesta por el dividendo, divisor, cociente y resto, de manera que:
#
#  **dividendo = divisor*cociente + resto.**
#
# Python nos permite calcular tanto el cociente como el resto de una división de manera sencilla.

# %% [markdown]
# **Cociente**
#
# Si queremos obtener el cociente (parte entera) de una división, debemos realizar la división con el operador **"//"**.
#
# El resultado de esta operación será siempre un número entero, aunque Python nos lo devolverá de tipo entero o decimal según sean el tipo del dividendo y el divisor.

# %%
20//6
# Out:
# 3

# %%
20.0//6
# Out:
# 3.0

# %%
20//6.0
# Out:
# 3.0

# %% [markdown]
# **Resto**
#
# Si, por otra parte, queremos obtener el resto de una división, debemos realizar la división con el operador **"%"**.
# Al igual que con el cociente, el tipo del valor obtenido dependerá del tipo de dato que sean el dividendo y el divisor.

# %%
20%6
# Out:
# 2

# %%
20.0%6
# Out:
# 2.0

# %%
20%6.0
# Out:
# 2.0

# %% [markdown]
# **divmod()**
#
# Por último, existe la manera de obtener de una única operación, tanto el cociente como el resto.
# Esto es posible gracias a la función integrada divmod(x,y), sobre la cual pasaremos como parámetro el dividendo (x) y el divisor (y), y Python nos devolverá una tupla con el cociente y el resto de la división.

# %%
divmod(20,6)
# Out:
# (3, 2)

# %% [markdown]
# #### Potencias y raíces

# %% [markdown]
# Las potencias se calculan con el operador "**". En esta ocasión, las potencias tienen prioridad sobre las multiplicaciones y divisiones (y por tanto, sobre las sumas y restas).
#
# ![potencias inversas y raices.PNG](data:image/png;base64,...)

# %%
5**2

# %%
2**-2

# %%
4**0.5

# %%
-9**0.5

# %%
(-9)**0.5

# %% [markdown]
# Adicionalmente, podemos utilizar la función integrada pow() para realizar el cálculo.

# %%
pow(5,2)

# %%
pow(2, -2)

# %%
pow(4, 0.5)

# %% [markdown]
# ####Funciones integradas y librerías

# %% [markdown]
# Finalmente, tenemos ciertas funciones integradas y librerías que nos ayudan con los cálculos matemáticos.

# %%
round(4.35)   # 4
round(4.63)   # 5
round(-4.35)   # -4
round(-4.63)   # -5

round(2.3456, 2)  # 2.35
round(2.3456, 0)  # 2.0 --> Float

round(12345, -1)  # 12340
round(12345, -2)  # 12300
# Out:
# 12300

# %% [markdown]
# En el caso de querer redondear voluntariamente al valor anterior o posterior, debemos importar la liberia **math** y realizar la operación llamando a la librería correspondiente.

# %%
import math

print(9/5)
print(math.floor(9/5)) ## entero más cercano menor o igual
print(math.ceil(9/5)) ## entero más cercano mayor o igual
# Out:
# 1.8
# 1
# 2

# %% [markdown]
# Por último, algunas de las funciones integradas más útiles para poder trabajar y operar con datos son:
#
#
# *   abs() : Nos devuelve el valor absoluto de un número.
# *   max() : calcula el valor máximo de un conjunto  de valores.
# *   min() : calcula el valor mínimo de un conjunto de valores.
# *   sorted(): ordena de manera ascendente (por defecto) un conjunto de valores. El conjunto de valores ha de ser un tipo de datos iterable (tupla, rango, lista, conjunto, diccionario)
# *   sum(): calcula la suma de un conjunto de valores. El conjunto de valores ha de ser un tipo de datos iterable (tupla, rango, lista, conjunto, diccionario)

# %%
abs(-4)

# %%
max(1,2,3,4,5)

# %%
min(1,-2,3,4,5)

# %%
sorted((10, 3, 5, -1, 14, -11))

# %%
sum((2, 4, 5, 10))

# %% [markdown]
# ### Cadenas de texto

# %% [markdown]
# Una cadena de texto es una secuencia de caracteres.
# Para delimitar una cadena de caracteres, utilizaremos las comillas simple (') o comillas dobles (").

# %%
print("Esto es una cadena")

# %%
print('Esto es una cadena')

# %%
print("Esto es una cadena')

# %% [markdown]
# #### Secuencias

# %% [markdown]
# Las cadenas de texto pueden manipularse de manera sencilla con ciertas funcionalidades básicas:
#
# **Slicing**
#
# ![image.png](data:image/png;base64,...)

# %%
"Python"[1]
# Out:
# 'y'

# %%
"Python"[-1]
# Out:
# 'n'

# %%
"Python"[0:3]
# Out:
# 'Pyt'

# %%
"Python"[-3:-2]

# %%
"Python"[0:4:2] # selecciona los caracteres de la cadena desde el índice 0 hasta el 3 (no incluye el 4), pero solo aquellos que están en posiciones que son múltiplos de 2 en ese rango.
# Out:
# 'Pt'

# %% [markdown]
# **Concatenación y multiplicación**

# %%
"Python" + " y Java"
# Out:
# 'Python y Java'

# %%
"Python " * 2
# Out:
# 'Python Python '

# %% [markdown]
# **Membresía**

# %%
"yth" in "Python"
# Out:
# True

# %%
"pepe" in "Python"
# Out:
# False

# %% [markdown]
# #### Funciones integradas

# %% [markdown]
# Existen ciertas funciones integradas que nos van a permitir operar y modificar las cadenas de texto de manera sencilla.

# %%
len("Python") #Nos devuelve número de caracteres de la cadena
# Out:
# 6

# %%
"Python".lower() #Convierte todos los caracteres en minúsculas
# Out:
# 'python'

# %%
"Python".upper() # Convierte toda la cadena a mayúsculas
# Out:
# 'PYTHON'

# %%
"Python está guay".title() # Convierte el primer caracter de cada palabra a mayúscula
# Out:
# 'Python Está Guay'

# %%
"Python está guay".replace("Python", "Beber cerveza") # Reemplaza los caracteres que queramos por otros
# Out:
# 'Beber cerveza está guay'

# %%
"Python está guay".find("t") # Nos devuelve el índice de la primera aparición de ese caracter
# Out:
# 2

# %%
"Python está guay".count("y") # Nos devuelve el número de apariciones del caracter o cadena que queramos
# Out:
# 2

# %%
" Python está guay ".strip() # Elimina el caracter especificado al principio y al final de la cadena (por defecto espacios)
# Out:
# 'Python está guay'

# %%
"Python está guay".strip("y")
# Out:
# 'Python está gua'

# %%
"Hey! Python mola".strip("Hey! ").replace("Python", "Beber cerveza").replace(" mola", " mola más aún") # Podemos concatenar tantas operaciones como queramos. Se ejecutan en orden de izquiera a derecha
# Out:
# 'Beber cerveza mola más aún'

# %% [markdown]
# ###Booleanos

# %% [markdown]
# Una variable booleana es aquella que solo puede tomar dos valores (True o False).
# En Python, cualquier valor puede convertirse a booleano. La lógica que se sigue para determinar si es True o False:
#
#
# *   Elementos nulos, vacíos o cero son considerados como **False**.
# *   Cualquier elemento que contenga algún valor distinto de cero será considerado **True**.
#
# Si queremos saber si un elemento se considera True o False, se puede convertir su valor mediante la función **bool()**.

# %%
bool(0)     # entero valor 0
## bool(0.0)   # float valor 0
##bool("")    # cadena texto valor 0
##bool(None)  # valor nulo
##bool(())    # tupla vacía
##bool([])    # lista vacía
##bool({})    # conjunto vacío
# Out:
# False

# %%
bool(1)
bool(-10)
bool("abcd")

# %% [markdown]
# #### Operadores lógicos

# %% [markdown]
# Los operadores lógicos son aquellos que nos van a permitir operar con los booleanos, y principalmente tenemos 3 tipos:
#
#
# *   **and**: Este operador nos devuelve True si se cumplen todas las condiciones de la operación
# *   **or**: Este operador nos devuelve True si se cumple al menos una condición de las planteadas.
# * **not**: Este operador nos devuelve True si el resultado de la operación es False.

# %%
True and True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# **Expresiones compuestas**
#
# Python te permite concatenar expresiones lógicas y hacer operaciones complejas. Para ello, es importante saber que Python evalúa primero los **not**, seguido de los **and**, y por último los **or**.
#
# Tip: si no estás acostumbrado a manejar estas expresiones, se recomienda utilizar paréntesis.

# %%
not True and False
#(not True) and False
#not (True and False)

# %%
not False or True
#(not False) or True
#not (False or True)

# %%
True or True and False
#(True or True) and False

# %% [markdown]
# **Operadores booleanos**
#
# Cuando queremos hacer alguna comprobación o determinar si se cumple alguna condición, tenemos una serie de operadores que nos permiten realizarlas, dando como resultado valores booleanos.
# Estos operadores son:
# ![image.png](data:image/png;base64,...)

# %%
5==5 and 2 > 1
# Out:
# True

# %%
9!=8 and 4+3 >= 8
# Out:
# False

# %%
9%2 == 0 or 9%3==0
# Out:
# True

# %%
min (2,4,5,1,0) == 1 or divmod(8,3) == (2,2)
# Out:
# True

# %%
not 10 > 9 or 4/-1+3 == 2
# Out:
# False

# %% [markdown]
# ##Variables

# %% [markdown]
# Podemos entender las variables como "cajas" o "etiquetas" que permiten hacer referencia a una expresión (asignado por ti o calculado), ya sea un valor numérico, booleano, una cadena, una estructura de datos...
#
# Esta posibilidad de "memorizar" es una de las capacidades más reconocibles de los lenguajes de programación.
#
# Para ello, la solución pasa por asignarle un nombre identificativo al valor que queramos memorizar.
#
# ¿Qué debemos saber de las variables?

# %% [markdown]
# ###Identificador único

# %% [markdown]
# La variable debe empezar por una letra o un guión bajo

# %%
calle = 'Alberto Aguilera'
_numero = 102

# %%
calle, _numero
# Out:
# ('Alberto Aguilera', 102)

# %% [markdown]
# Es sensible a las mayúsculas/minúsculas

# %%
nombre = 'Diego'
Nombre = 'CEI'

# %%
nombre
# Out:
# 'Diego'

# %% [markdown]
# No se pueden utilizar palabras clave

# %%
if else for while int type float str
nombre Nombre

# %% [markdown]
# Para ayudarnos a saber qué contienen, los nombres han de ser descriptivos y mínima longitud:

# %%
ticket_medio_usuarios_ultimo_mes # 32 caracteres
med_ult_mes                      # 10 caracteres

a = 345
b = 678

# %% [markdown]
# Tipos de notacion
#
# camel case
# motivoReclamo
#
# pascal case
# MotivoReclamo
#
# lower case
# motivoreclamo
#
# upper case
# MOTIVORECLAMO

# %% [markdown]
# ###Los tipos

# %% [markdown]
# Una gran ventaja de Python es que no es necesario definir el tipo de una variable, y este se asigna automáticamente en función del valor asignado.

# %%
my_var = 'Soy una cadena'
print(type(my_var))
my_var = 30
print(type(my_var))
my_var = 14.5
print(type(my_var))
my_var = False
print(type(my_var))

# %% [markdown]
# De igual manera que vimos que las variables eran sensibles a mayúsculas, el lenguaje está fuertemente tipado, lo que provoca que no puedan combinarse fácilmente variables de distinto tipo.

# %%
a = 'Diego'
b= 31
a+b
# Out:
# 'Diego 31'

# %% [markdown]
# Una vez tenemos guardado un valor en una variable, podemos hacer referencia a ese valor a través de la variable en el momento que queramos.

# %%
a = 2
b = 3
c = a+b
c
# Out:
# 5

# %% [markdown]
# **Asignaciones aumentadas**
#
# Cuando una variables se modifica a partir de su propio valor, esto se denomina "asignación aumentada". Por ejemplo
# * a= a+b --> a+=b
# * a= a-b --> a-=b
# * a= a/b --> a/=b
#
# **Definir y modificar varias variables a la vez**
#
# En una misma línea se pueden definir simultáneamente varias variables, con un mismo valor o con valor distinto. Por ejemplo:
#
#
#
# ```
# a = b = 99
# nombre, apellido1, apellido2 = "Carlos", "González", "Martínez"
# ```

# %%
a = b = 99
nombre, apellido1, apellido2, = "Carlos", "González", "Martínez"

a, b, nombre, apellido1, apellido2
# Out:
# (99, 99, 'Carlos', 'González', 'Martínez')

# %%
apellido1

# %% [markdown]
# ####Conversión de tipos

# %% [markdown]
# Python nos permite convertir los datos a otros tipos (siempre que el dato sea compatible). Para ello, tenemos ciertas funciones integradas que lo permiten:
#
#
# *   int(variable) : convierte la variable a tipo entero.
# *   float(variable) : convierte la variable a tipo decimal.
# * bool(variable) : convierte la variable a tipo booleano.
# * str(variable) : convierte la variable a tipo cadena de texto.

# %%
variable = 80
float(variable)

# %%
bool(variable)

# %%
str(10) + " pepe"
# Out:
# '10 pepe'

# %%
variable2 = "CEI"
int(variable2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-1870291beea5> in <cell line: 0>()
#       1 variable2 = "CEI"
# ----> 2 int(variable2)
#
# ValueError: invalid literal for int() with base 10: 'CEI'

# %% [markdown]
# ### Ejercicios

# %% [markdown]
# 1.   Escribir un programa para reemplazar todas las apariciones de la letra "r" por la letra "b" en una cadena ingresada por teclado.
#
# 2.   Escribir un programa que convierta las 3 últimas letras de una cadena en mayúsculas.
#
# derecha = cadena[-3:]
#
# 3. Tomas un préstamo en una oficina bancaria para comprar una casa con una tasa de interés simple del 2% durante 5 años. ¿Cuántos intereses habrás pagado después de 24 meses?
#
# 4. Tienes una deuda de 20k€ y descubres que tu banco ofrece un depósito con un tipo de interés compuesto anual del 3%. ¿Cuánto dinero debes invertir para poder pagar la deuda en 3 años?
#
# deuda=20000
#
# tasa_interes=0.03
#
# años=3
#
# inversion = deuda / (1 + tasa_interes)**años
#
# inversion
#
#
#
# 5. Cuál será el resultado de la siguiente expresión?
# Piénsalo antes de ejecutar el código!
#
#
# ```
# not (("testing"!="Testing) or ("Python" == "Python "))
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Ejercicios adicionales**
#
# **Desafío 1: Crear el juego piedra papel tijera.**
#
# Ingresar por pantalla elección:
# 1-roca
# 2-papel
# 3-tijera
#
# Luego mediante random, la computadora elije un numero comprendido entre 1 y 3
#
# Validar quien ganó de acuerdo a las reglas del juego
#
# Mostrar mensaje por pantalla de ganador:
#
# Humano ganó
#
# Computadora ganó
#
# computer_choice = random.choice(options)
#         print(f"La computadora eligió: {computer_choice}")
#
#         if user_choice == computer_choice:
#             print("¡Empate!")
#         elif (user_choice == "piedra" and computer_choice == "tijera") or \
#              (user_choice == "papel" and computer_choice == "piedra") or \
#              (user_choice == "tijera" and computer_choice == "papel"):
#             print("¡Ganaste!")
#         else:
#             print("¡Perdiste!")

# %% [markdown]
# **Desafío 2: Mostrar en un mapa la ubicación actual**
#
# Aclaraciones:
# - Utilizar el mapa de leaflet
# - El mapa necesita la latitud y la longitud
# - Lat y Lon se obtienen ejecutando el servicio: https://ipinfo.io/[ip publica]?token=18d8c3b1e6add3
# - La IP publica se obtiene con el servicio: https://ipecho.net/
#
# Pueden utilizar servicios alternativos en caso que exista diferencia en el resultado de la ubicación

# %%
## DESAFIO 2 RESUELTO

## 1. la ip publica se obtiene de la siguiente web: https://nordvpn.com/es/what-is-my-ip/
ipPublica = "62.175.82.73"

## 2. geolocalizar la ip publica
import requests ## importar la libreria request para trabajar con sitios web
url = "https://ipinfo.io/" + ipPublica + "?token=18d8c3b1e6add3" ## servicio que obtiene la ubicación geográfica a través de la dirección ip
response = requests.get(url) ## esta función se utiliza para obtener datos de un servidor web a través de la URL proporcionada
contenido = response.text ## obtener el contenido del sitio web
contenido

## 3. convertir el contenido JSON a un diccionario de Python
import json ## importar la libreria para utilizar estructuras JSON
objeto_python = json.loads(contenido) ## cargar en variable objeto_python, el contenido
ciudad = objeto_python.get("city") ## obtener de la estructura JSON el valor de city
provincia = objeto_python.get("region")
pais = objeto_python.get("country")
latlon = objeto_python.get("loc")
latitud = latlon.split(",")[0] ## con latlon en la estructura JSON tiene una dupla, debo separarla co [0] y [1] respectivamente
longitud = latlon.split(",")[1]

# 4. mostrar un mapa con la ubicación actual aproximada
# !pip install ipyleaflet ## instalar las librerías necesarias
from ipyleaflet import Map, Marker ## importar las librerías necesarias

m = Map(center=(latitud, longitud), zoom=12) ## crear un mapa centrado con la ubicación aproximada
marker = Marker(location=(latitud, longitud), title="Ciudad: " + ciudad + ". Provincia: " + provincia + ". Pais: " + pais) ## crear un marcador con la ubicación geográfica
m.add_layer(marker) ## agregar el marcador al mapa

m ## mostrar el mapa
# Out:
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.11/dist-packages (0.19.2)
# Requirement already satisfied: branca>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (0.8.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (7.7.1)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in /usr/local/lib/python3.11/dist-packages (from ipyleaflet) (2024.9.0)
# Requirement already satisfied: jinja2>=3 in /usr/local/lib/python3.11/dist-packages (from branca>=0.5.0->ipyleaflet) (3.1.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.13)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (3.0.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (7.16.5)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.11/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.1.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipyleaflet) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.22.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.3.1)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.1 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2
# Map(center=['39.4752', '-0.4183'], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…
