# %% [markdown]
# <a href="https://colab.research.google.com/github/elisacisnerose/clasesCEI/blob/main/9_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fundamentos de Python y estructuras de control - Diego Martínez

# %% [markdown]
# ## Funciones

# %% [markdown]
# Una función permite definir un bloque de código reutilizable que se puede ejecutar muchas veces dentro de un programa.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **¿Qué ventajas me proporciona crear funciones?**
#
# 1. Reutilización de código : una de las principales ventajas de crear funciones es que puedes definir un conjunto de instrucciones una vez y luego reutilizarlo en múltiples lugares dentro de tu programa. Esto evita la duplicación de código y facilita el mantenimiento.
#
# 2. Abstracción : las funciones permiten encapsular detalles complejos en un solo lugar y proporcionar una interfaz simple para usar. Los usuarios de la función no necesitan conocer todos los detalles internos, lo que simplifica el uso del código.
#
# 3. Claridad y legibilidad del código : usar funciones con nombres descriptivos ayuda a que tu código sea más claro y legible. En lugar de tener un programa largo y difícil de entender, puedes dividirlo en funciones con nombres que indiquen claramente su propósito.
#
# 4. Modularidad : la modularidad es un principio de diseño de software que consiste en dividir un programa en partes más pequeñas y manejables (módulos o funciones). Esto hace que el código sea más fácil de mantener y depurar, ya que cada función se ocupa de una tarea específica.
#
# 5. Facilita la depuración : si encuentras un error en tu código, es más fácil identificar y solucionar el problema si has dividido tu programa en funciones más pequeñas y autónomas. Puedes aislar y probar cada función individualmente.
#
# 6. Facilita la colaboración : cuando trabajas en un proyecto con otros programadores, las funciones proporcionan un mecanismo claro para dividir el trabajo y colaborar de manera efectiva. Cada miembro del equipo puede trabajar en funciones específicas sin interferir en el trabajo de los demás.
#
# 7. Reutilización en proyectos futuros : una vez que haya creado una función útil en Python, puede reutilizarla en proyectos futuros sin tener que volver a escribirla desde cero. Esto ahorra tiempo y esfuerzo.

# %% [markdown]
# En pseudocódigo, una función podría tener esta estructura
#
#
#
# ```
# # def nombre_funcion (parametros):
#   bloque instrucciones
#   return?
# ```

# %% [markdown]
# Por ejemplo, si quisiera hacer la suma entre dos números:

# %%
a=5
b=4
c=a+b
print(f"Suma manual: {c}")

def suma(n1, n2):
  sum = n1+n2
  return sum

print(f"Suma función 1: {suma(a,b)}")
print(f"Suma función 2: {suma(3,2)}")
# Out:
# Suma manual: 9
# Suma función 1: 9
# Suma función 2: 5

# %%
# Out:
# 12
# 12

# %% [markdown]
# Si quisiéramos centralizar y agrupar una serie de tareas repetitivas, como puede ser la limpieza y tratamiento de unos nombre y apellidos:

# %%
lista_clientes = []

entrada = " Fernando Ramos "
entrada = entrada.strip()
nombre, apellido = entrada.split()
lista_clientes.append([nombre, apellido])

entrada = "Rocío Arbonez "
entrada = entrada.strip()
nombre, apellido = entrada.split()
lista_clientes.append([nombre, apellido])

entrada = "Araceli Gálvez "
entrada = entrada.strip()
nombre, apellido = entrada.split()
lista_clientes.append([nombre, apellido])

print(lista_clientes)
# Out:
# [['Fernando', 'Ramos'], ['Rocío', 'Arbonez'], ['Araceli', 'Gálvez']]

# %%
lista_clientes = []

def nombres(entrada):
  entrada = entrada.strip()
  nombre, apellido = entrada.split()
  lista_clientes.append([nombre, apellido])

nombres(" Fernando Ramos ")
nombres("Rocío Simón ")
nombres("Araceli Gálvez ")

print(lista_clientes)
# Out:
# [['Fernando', 'Ramos'], ['Rocío', 'Simón'], ['Araceli', 'Gálvez']]

# %% [markdown]
# Para las funciones tenemos algo importante que es el valor de retorno, o el **return**. Muchas veces podemos confundir este comando con el **print**.
#
# El **print()** imprime el valor en la consola, mientras que el **return** devuelve el valor que luego se puede imprimir en la consola, o almacenarlo en una variable para su uso futuro.

# %%
def my_func1():
  return 35

x = my_func1()
print(x)
# Out:
# 35

# %%
def my_func2():
  print(35)

x = my_func2()
print(x)
# Out:
# 35
# None

# %% [markdown]
# El **return**, además, sirve para detener la ejecución de la función cuando se cumple una determinada condición.

# %%
import random

def adivina_el_numero():
  numero = random.randrange(0,10)
  entrada = int(input("Introduzca un número: "))
  while entrada != numero:
    entrada = input("Introduzca un número: ")
    if entrada == 'SALIR':
      return -1
    entrada = int(entrada)
  return numero

num = adivina_el_numero()

if num == -1:
  print("El jugador se ha rendido y no ha acertado")
else:
  print(f"¡Has acertado! El valor buscado era {num}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-99c552eb4e54> in <cell line: 0>()
#      11   return numero
#      12
# ---> 13 num = adivina_el_numero()
#      14
#      15 if num == -1:
#
# <ipython-input-5-99c552eb4e54> in adivina_el_numero()
#       3 def adivina_el_numero():
#       4   numero = random.randrange(0,10)
# ----> 5   entrada = int(input("Introduzca un número: "))
#       6   while entrada != numero:
#       7     entrada = input("Introduzca un número: ")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %% [markdown]
# Existe la posibilidad de que una función acepte parámetros por defecto. Para ello, en la declaración y creación de la función, pondremos como último parametro el valor que debería tener ese valor en caso de no encontrarse en la llamada.
#
# **Importante:** siempre se ponen al final.

# %%
def my_func (a, b, c=5):
  return a+b+c

print(my_func(1,1))
print(my_func(1,1,3))
# Out:
# 7
# 5

# %%
def my_func2 (c=5, a, b):
  return a+b+c

print(my_func(a=1, b=1))

# %% [markdown]
# También existe la posibilidad de que, a priori, no vayamos a saber cuántos parámetros se pueden pasar a la función. En ese caso tenemos el comando *args. Lo que vaya dentro de este parámetro, se almacenará como una tupla.

# %%
def my_func(a,b,*args):
  print(a)
  print(b)
  print(args)
  print(type(args))
  print(max(args))
  return a+b+max(args)

my_func(1,3,5,6,5,4,3)
# Out:
# 1
# 3
# (5, 6, 5, 4, 3)
# <class 'tuple'>
# 6
# 10

# %% [markdown]
# Esta misma funcionalidad la tenemos para el recibimiento de parámetros en forma clave-valor. En este caso la tenemos mediante el comando **kwargs. Lo que vaya dentro de este parámetro, Python lo interpretará como un diccionario.

# %%
def my_func(a,b, **kwargs):
  print(type(kwargs))
  print(kwargs)

my_func(1,2, k1=3, k2=4, k3= 10)

# %%
def my_func(a,b,*args, **kwargs):
  print(args)
  print(kwargs)

my_func(1,1,2,3,4,k1=3, k2=4)

# %% [markdown]
# **Encapsulamiento de las variables en las funciones**
#
# En Python, las variables que se encuentran referenciadas dentro de una función son **globales** implícitamente.
#
# En cambio, si a una variable se la asigna un valor en cualquier lugar dentro del cuerpo de una función, se asumirá que es **local** a no ser que explícitamente se la declare como global.
#
# Es decir, Python primero mira si hay una variable local con ese nombre. En caso de que exista, utiliza esa variable. Si no existe, comprueba que haya una variable global (fuera de la función) con ese valor. Si tampoco existe, muestra error.

# %%
tipo = "global"

def global_func():
  print(f"Mi variable es {tipo}")

def local_func():
  tipo = "local"
  print(f"Mi variable es {tipo}")

global_func()
local_func()
print(tipo)
# Out:
# Mi variable es global
# Mi variable es local
# global

# %% [markdown]
# Por otra parte, todo aquello que se declara dentro de una función, se queda en la función.

# %%
def decl_local_var(): # def permite declarar una funcion, () en este caso no acepta parametros
  nuevo_nombre = "Nueva variable" # creo una variable
  print(nuevo_nombre) # imprimo la variable
#termina la funcion

decl_local_var() #ejecuto la funcion
# Out:
# Nueva variable

# %%
var = "Hola "

def doble_saludo():
  print(var*2)

doble_saludo()

# %%
var = "Hola "

def doble_saludo():
  var = var*2
  print(var)

doble_saludo()

# %% [markdown]
# En el caso que queremos modificar una variable global dentro de una función (entorno local), lo que necesitaremos será declarar esa variable como global dentro de la función.

# %%
var = "Hola "

def doble_saludo():
  global var
  var = var*2
  print(var)

doble_saludo()
print(var)
# Out:
# Hola Hola
# Hola Hola

# %% [markdown]
# **Funciones lambda**
#
# Las funciones lambda están diseñadas para operaciones simples, a menudo para hacer transformaciones de datos o filtros de manera rápida.
#
#
#
# ```
# # f = lambda a: a*a (por ejemplo)
# ```
#
# Las funciones **lambda** van de la mano de dos comandos:
# * Map: para ejecutar una función sobre todos los elementos de un objeto iterable.
# * Filter: para filtrar los elementos de un objeto iterable

# %%
mi_lista = list(range(10))

mi_lista2 = list(map(lambda elemento: elemento*elemento, mi_lista))
print(mi_lista2)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
mi_lista = list(range(10))

mi_lista3 = list(filter(lambda elemento: elemento%2==0, mi_lista))
print(mi_lista3)
# Out:
# [0, 2, 4, 6, 8]

# %%
# Convertir a mayuscula los items de una lista
nombres = ["juan", "ana", "carlos"]

nombres_en_mayuscula = list(map(str.upper, nombres))
print(nombres_en_mayuscula)
# Out:
# ['JUAN', 'ANA', 'CARLOS']

# %%
# La funcion lambda permite definir funciones anónimas (sin nombre) en una sola línea.
# Se usan cuando necesitas una función simple y rápida sin la necesidad de definirla con def
# lambda argumentos: expresión

# Sumar dos numeros
suma = lambda a, b: a + b
print(suma(5, 3))

# Elevar un numero al cuadrado
cuadrado = lambda x: x**2
print(cuadrado(4))

# #Elevar al cuadrado los numeros de una lista
numeros = [1, 2, 3, 4, 5]
cuadrados = list(map(lambda x: x**2, numeros))
print(cuadrados)  # Salida: [1, 4, 9, 16, 25]
# Out:
# 8
# 16
# [1, 4, 9, 16, 25]

# %% [markdown]
# #### Ejercicios

# %% [markdown]
# 1. Escribir una función que devuelva un número a la potencia de 2.
# 2. Escribir una función que acepte una cadena de texto y calcule el número mayúsculas, minúsculas y espacios.
# 3. Escribir una función que acepte un número indeterminado de números y sume solo los impares.
# 4. Escribir una función que reemplace la letra "r" por la "b" de una variable global creada fuera de la función. var_global = "Acércame el tornillo y el destornillador".
# 5. Escribir un programa que, partiendo de una lista de nombre, ponga todos los nombres en forma de título (primera en mayúscula y el resto minúsculas). Pista: map()
# 6. Escribir un programa que, en base a lo obtenido en el ejercicio anterior, filtre todos los nombre que comiencen por "Ma". Pista: filter()

# %%
# 1
def potencia_de_dos(numero): # def indica que estoy creando una funcion, (numero)
  resultado = numero ** 2
  return resultado # retorna el numero elevado a la potencia de dos

potencia_de_dos(3) # ejecuto la funcion enviando como parametro el numero 3
# Out:
# 9

# %%
# 2
def contar(texto):
  mayusculas = 0
  minusculas = 0
  espacios = 0

  for caracter in texto:
    if caracter.isupper():
      mayusculas +=1

    if caracter.islower():
      minusculas +=1

    if caracter== " ":
      espacios +=1

  print(mayusculas, minusculas, espacios)

contar("Hola como estas!, Todo muy bien por suerte")

# %%
# 3
def suma_impares(numeros):
  suma = 0
  for numero in numeros:
    if numero % 2 != 0: # pregunto si el resto de la division por dos del numero es distinto de cero, entonces es impar
      suma += numero
  return suma

suma_impares([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 25
