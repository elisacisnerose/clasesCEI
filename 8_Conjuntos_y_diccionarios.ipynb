# %% [markdown]
# <a href="https://colab.research.google.com/github/elisacisnerose/clasesCEI/blob/main/8_Conjuntos_y_diccionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Fundamentos de Python y estructuras de control

# %% [markdown]
# ## Estructuras de datos

# %% [markdown]
# Python nos ofrece una serie de estructuras de datos en las cuales podemos almacenar nuestros datos de manera ordenada y con posibilidad de acceder a ellos de manera lógica. Hay cuatro tipos de estructura:
#
# * **Listas**
#
# > * Datos heterogéneos
# * Acepta repetidos
# * Elementos mutables
# * Accesibles por índice
# >
#
# * **Tuplas**
#
# > * Datos heterogéneos
# * Acepta repetidos
# * Elementos **inmutables**
# * Accesibles por índice
# >
#
# * **Conjuntos**
#
# > * Datos heterogéneos
# * **No admite repetidos**
# * Elementos **inmutables**
# * **No accesibles por índice**
# >
#
# * **Diccionarios**
#
# > * Datos heterogéneos
# * Acepta repetidos
# * Claves de tipos **inmutables y únicas**
# * **Accesibles por clave**

# %% [markdown]
# ### Conjuntos

# %% [markdown]
# Los conjuntos son otra estructura de datos similar a las listas y las tuplas pero más restrictivos. En este caso, los elementos deben ser inmutables, no se almacenarán elementos repetidos y no son accesibles por índice.

# %%
set1 = set()
print(set1)
set1 = {0}
print(set1)
# Out:
# set()
# {0}

# %%
set1 = {"Diego", 31, True} #Admite datos heterogéneos

# %% [markdown]
# Al conjunto podemos pasarle valores repetidos, pero solo se quedarán los valores únicos.

# %%
datos = [1,1,2,4,6,5,5,4,10]
conj = set(datos)
print(conj)
# Out:
# {1, 2, 4, 5, 6, 10}

# %% [markdown]
# Como funciones específicas de conjuntos tenemos:

# %%
my_set = {"A", "E", "I", "O"}
print(my_set)
my_set.add("U") # Añadir un elemento
print(f"Add: {my_set}")
my_set.update(["B", "C"]) # Añadir varios elementos
print(f"Update: {my_set}")
my_set.remove("I")  # Elimina un elemento y genera un error si el elemento no existe
print(f"Remove: {my_set}")
my_set.discard("A") # Elimina un elemento pero no genera error si el elemento no existe.
print(f"Discard: {my_set}")
my_set.clear()      # Elimina todos los elementos de un conjunto
print(f"Clear: {my_set}")
# Out:
# {'I', 'E', 'A', 'O'}
# Add: {'E', 'A', 'O', 'U', 'I'}
# Update: {'E', 'A', 'C', 'O', 'B', 'U', 'I'}
# Remove: {'E', 'A', 'C', 'O', 'B', 'U'}
# Discard: {'E', 'C', 'O', 'B', 'U'}
# Clear: set()

# %% [markdown]
# Los conjuntos tienen una serie de métodos propios para combinar varios conjuntos entre sí.
#
# ![image.png](data:image/png;base64,...)

# %%
a = {1,2,3,4}
b = {3,4,5,6}

# %%
intersection = a&b
print(intersection)
# Out:
# {3, 4}

# %%
union = a|b
print(union)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
difference = a-b
print(difference)
# Out:
# {1, 2}

# %%
symmetric_difference = a^b
print(symmetric_difference)
# Out:
# {1, 2, 5, 6}

# %%
a<=b
# Out:
# False

# %%
c = {2,3,4}
d = {2,3,4}

# %%
c <= d
# Out:
# True

# %% [markdown]
# #### Ejercicios

# %% [markdown]
# 1. Tenemos dos conjuntos (A y B), de los que queremos saber:
#
# A = {2,3,4,5,6,7,9,11,13,15,17}
# B = {1,2,3,10,11,15,20,23}
# * Todos los elementos distintos de ambos conjuntos.
# * Todos los elementos que coinciden en ambos conjuntos.
# * Todos los elementos que están en A y no en B.
# * ¿A es un subconjunto de B?
#
# 2. Escriba un programa que compruebe si una lista tiene elementos duplicados.
# 2. Escriba un nuevo conjunto a partir del conjunto A= {1,2,3,4,5}, cuyos valores sean el cuadrado de los elementos del conjunto A.
#
# 4. Queremos lanzar una comunicación comercial a nuestros clientes que sean menores de 40 años y residentes en Madrid con el fin de informarles acerca de nuestras hipotecas.
# * De la comunicación debemos eliminar aquellos clientes que no acepten publicidad y que ya tengan contratada una hipoteca. Además, debemos incluir a unos empleados en la campaña para que comprueben que la comunicación se realiza de manera correcta.
#
# * Por otra parte, el equipo de analítica avanzada nos ha proporcionado un grupo de clientes que han detectado como propensos a la contratación. Debemos impactar a este grupo de manera independiente, asegurándonos de que también hayamos eliminado a los clientes que no aceptan publicidad, que ya tengan una hipoteca contratada y habiendo añadido a los empleados de prueba.
#
# * Debemos asegurarnos de que los clientes propensos no estén en el grupo de menores de 40 años de Madrid.
#
# > * ¿A cuántos clientes impactamos finalmente del grupo de menores de 40 años de Madrid? ¿Y de los propensos?
# * ¿A cuántos clientes hemos dejado de impactar por no aceptar publicidad y tener hipoteca contratada?
# * ¿Cuántos clientes de los propensos estaban en el grupo de menores de 40 años de Madrid?
#
# base_menores_40 = {65,1,5,22,19,77,18,64,91,32,67,69,26,86,97,63,96,36,76,83,56,80,87,95,20,10,45,74,17,13,52,62,58,60,9,71,88,89,11,34,55,51,7,24,28,68,79,54,14,57,93,6,21,23,3,25,29,72,90,30,43,53,8,78,73,4,81,0,15,42}
#
# base_madrid ={62,27,88,44,58,51,7,4,86,25,78,84,64,37,13,97,92,96,22,43,83,57,15,98,10,47,80,32,73,19,91,48,33,59,52,69,87,26,29,95,20,11,77,28,76,8,53,14,35,72}
#
# no_publi = {98,30,23,2,54,7,55,50,72,11,41,56,20,73,84,69,33,27,21,4,19,39,16,35,12,25,91}
#
# hipoteca = {47,28,26,15,9,86,32,56,64,36,29,42,31}
#
# propensos = {57,33,49,42,54,22,71,29,36,4,66,31,17,51,45,85,41,12,39,1}
#
# empleados = {30,84,4}

# %%
# 1
A = {2,3,4,5,6,7,9,11,13,15,17}
B = {1,2,3,10,11,15,20,23}

#Todos los elementos distintos de ambos conjuntos.
print(A^B)

#Todos los elementos que coinciden en ambos conjuntos.
print(A.intersection(B))

#Todos los elementos que están en A y no en B.
print(A-B)

#¿A es un subconjunto de B?
print(A.issubset(B))

# %%
# 2. Escriba un programa que compruebe si una lista tiene elementos duplicados
A = {2,2,2,3,4,5,6,7,9,11,13,15,17}
B = set(A)

print(A)
print(B)
# Out:
# {2, 3, 4, 5, 6, 7, 9, 11, 13, 15, 17}
# {2, 3, 4, 5, 6, 7, 9, 11, 13, 15, 17}

# %%
# 3. Escriba un nuevo conjunto a partir del conjunto A= {1,2,3,4,5}, cuyos valores sean el cuadrado de los elementos del conjunto A.
A = {1,2,3,4,5}
AalCuadrado = {numero**2 for numero in A}
AalCuadrado
# Out:
# {1, 4, 9, 16, 25}

# %% [markdown]
# ### Diccionarios

# %% [markdown]
# Un diccionario es una estructura de datos en la que cada posición está representada por un par clave-valor. Se declaran con **{}**, al igual que con los conjuntos.

# %%
dict = dict()
dict = {}

# %%
dic1 = {"Temperatura": 31, "Humedad": 38, "Viento": 35}
dic2 = dict([("Temperatura", 31), ("Humedad", 38), ("Viento", 35)])
dic3 = dict(Temperatura=31, Humedad=38, Viento=35)

print(dic1)
print(dic2)
print(dic3)
# Out:
# {'Temperatura': 31, 'Humedad': 38, 'Viento': 35}
# {'Temperatura': 31, 'Humedad': 38, 'Viento': 35}
# {'Temperatura': 31, 'Humedad': 38, 'Viento': 35}

# %% [markdown]
# Los elementos del diccionario no son accesibles por índices si no por claves. Además, el membership se comprueba con las claves.

# %%
print(len(dic1))
print(dic1["Temperatura"])
print("Humedad" in dic1)
# Out:
# 3
# 31
# True

# %% [markdown]
# Otras funciones de diccionarios para su manejo:

# %%
dic1 = {"Temperatura": 31, "Humedad": 38, "Viento": 35}
dic1["Polen"] = 31 # Añadir nuevo valor al diccionario
print(dic1)
dic1.pop("Polen") # Eliminar un elemento
print(dic1)
del dic1["Humedad"]
print(dic1)
dic1.clear()
print(dic1)
del dic1
# Out:
# {'Temperatura': 31, 'Humedad': 38, 'Viento': 35, 'Polen': 31}
# {'Temperatura': 31, 'Humedad': 38, 'Viento': 35}
# {'Temperatura': 31, 'Viento': 35}
# {}

# %%
dic1 = {"Temperatura": 31, "Humedad": 38, "Viento": 35}
print(dic1.keys()) # Accedemos a las claves
print(dic1.values()) # Accedemos a los valores
print(dic1.items()) # Cogemos el diccionario en forma de lista de tuplas
# Out:
# dict_keys(['Temperatura', 'Humedad', 'Viento'])
# dict_values([31, 38, 35])
# dict_items([('Temperatura', 31), ('Humedad', 38), ('Viento', 35)])

# %% [markdown]
# Una clave de un diccionario debe ser de un tipo inmutable. Se puede utilizar un entero, flotante, cadena, booleano o tupla. Una **lista** no puede ser clave de un diccionario

# %%
my_dict = {1: 34, 3.0:67, "hello": 89, True: 89, (1,2): 45}

# %% [markdown]
# Si queremos concatenar diccionarios, podemos utilizar la función **update()**, o concatenarlos mediante {* *diccionario1, * *diccionario2}

# %%
dict0 = {"Cuenta1": 9.5, "Cuenta2": 8, "Cuenta3": 7.4}
dict1 = {"Cuenta4": 12.3, "Cuenta5": 17, "Cuenta6": 5}

dict0.update(dict1)
dict0
# Out:
# {'Cuenta1': 9.5,
#  'Cuenta2': 8,
#  'Cuenta3': 7.4,
#  'Cuenta4': 12.3,
#  'Cuenta5': 17,
#  'Cuenta6': 5}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Ejercicios

# %% [markdown]
# 1. Escribir un programa para concatenar los siguientes diccionarios:
# * dic1 = {1:10, 2:20}
# * dic2 = {3:30, 4:40}
# * dic3 = {5:50, 6:60, 1:70}
#
# 2. Escriba un programa que le pida al usuario introducir su nombre y su calificación (separado por una coma), y lo agregue a un diccionario. El usuario podrá meter nombres y calificaciones hasta que escriba por teclado "-1".
#
# 3. Partiendo del ejercicio anterior, calcula la nota media de todos los alumnos introducidos.

# %%
# Crear un menu de opciones en tres idiomas. Preguntar al usuario el idioma a utilizar

diccionario_Ingles = {"guardar": "Save", "cancelar": "Cancel", "abrir": "Open", "menu principal":"Main menu", "selecciona una opcion":"Select an option"}
diccionario_Espanol = {"guardar": "Guardar", "cancelar": "Cancelar", "abrir": "Abrir", "menu principal":"Menú principal", "secciona una opcion":"Selecciona una opción"}
diccionario_Frances = {"guardar": "Enregistrer", "cancelar": "Annuler", "abrir": "Ouvrir", "menu principal":"Menu principal", "selecciona una opcion": "Sélectionnez une option"}

idioma=input("Selecciona idioma (1. English, 2. Español, 3. Française): ")

if idioma=="1":
  print(diccionario_Ingles["menu principal"])
  print("")
  print("1. " + diccionario_Ingles["guardar"] )
  print("2. " + diccionario_Ingles["cancelar"])
  print("3. " + diccionario_Ingles["abrir"])
  print("")
  opcion=input(diccionario_Ingles["selecciona una opcion"])

if idioma=="2":
  print(diccionario_Espanol["menu principal"])
  print("")
  print("1. " + diccionario_Espanol["guardar"] )
  print("2. " + diccionario_Espanol["cancelar"])
  print("3. " + diccionario_Espanol["abrir"])
  print("")
  opcion=input(diccionario_Espanol["selecciona una opcion"])

if idioma=="3":
  print(diccionario_Frances["menu principal"])
  print("")
  print("1. " + diccionario_Frances["guardar"] )
  print("2. " + diccionario_Frances["cancelar"])
  print("3. " + diccionario_Frances["abrir"])
  print("")
  opcion=input(diccionario_Frances["selecciona una opcion"])
# Out:
# Selecciona idioma (1. English, 2. Español, 3. Française): 3
# Menu principal
#
# 1. Enregistrer
# 2. Annuler
# 3. Ouvrir
#
# Sélectionnez une option2

# %%
idioma=input("Selecciona idioma (1. English, 2. Español, 3. Française): ")

def traductor(key):
  diccionario_Ingles = {"guardar": "Save", "cancelar": "Cancel", "abrir": "Open", "menu principal":"Main menu", "selecciona una opcion":"Select an option"}
  diccionario_Espanol = {"guardar": "Guardar", "cancelar": "Cancelar", "abrir": "Abrir", "menu principal":"Menú principal", "secciona una opcion":"Selecciona una opción"}
  diccionario_Frances = {"guardar": "Enregistrer", "cancelar": "Annuler", "abrir": "Ouvrir", "menu principal":"Menu principal", "selecciona una opcion": "Sélectionnez une option"}

  if idioma=="1":
    return diccionario_Ingles[key]
  if idioma=="2":
    return diccionario_Espanol[key]
  if idioma=="3":
    return diccionario_Frances[key]

print(traductor("menu principal"))
print("")
print("1. " + traductor("guardar"))
print("2. " + traductor("cancelar"))
print("3. " + traductor("abrir"))
print("")
opcion=input(traductor("selecciona una opcion"))
# Out:
# Selecciona idioma (1. English, 2. Español, 3. Française): 1
# Main menu
#
# 1. Save
# 2. Cancel
# 3. Open
#
# Select an option1

# %%
# 1
dic1 = {1:10, 2:20}
dic2 = {3:30, 4:40}
dic3 = {5:50, 6:60, 1:70}

dic4 = {}
dic4.update(dic1)
dic4.update(dic2)
dic4.update(dic3)

dic4
# Out:
# {1: 70, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
# 2
diccionario_calificaciones = {}

while True:
  entrada = input("Introduce el nombre y la calificación (separados por coma), o -1 para terminar: ")
  if entrada == "-1":
    break #termina el ciclo while

  clave, valor = entrada.split(",") #nombre y calificacion separados por coma
  clave = clave.strip() #quito blancos al inicio y al fin
  valor = int(valor.strip()) #convierto la calificacion a entero
  diccionario_calificaciones[clave] = valor #agrego al diccionario el nuevo item de clave-valor

diccionario_calificaciones
# Out:
# Introduce el nombre y la calificación (separados por coma), o -1 para terminar: julia,8
# Introduce el nombre y la calificación (separados por coma), o -1 para terminar: ariel,5
# Introduce el nombre y la calificación (separados por coma), o -1 para terminar: pedro,9
# Introduce el nombre y la calificación (separados por coma), o -1 para terminar: -1
# {'julia': 8, 'ariel': 5, 'pedro': 9}

# %%
# 3
sumatotal = sum(diccionario_calificaciones.values())
cantidad = len(diccionario_calificaciones)
promedio = sumatotal / cantidad
promedio
# Out:
# 7.333333333333333

# %%
# Filtro inteligente
peliculas=["secreto mar","mar y tierra","el laberinto","mar adentro","El secreto de tus ojos","Volver","Amores perros","La piel que habito"]
filtro="aden mar"
filtroPalabras=filtro.split(" ")

resultado=[]
existe=False

for pelicula in peliculas:
  existe=True

  for filtroPalabra in filtroPalabras:
    if filtroPalabra not in pelicula:
      existe=False

  if existe:
    resultado.append(pelicula)

print(resultado)
# Out:
# ['mar adentro']
